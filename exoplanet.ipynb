# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("exoplanet.csv")

# %%
df
# Out:
#       rowid pl_hostname pl_letter     pl_name    pl_discmethod  pl_pnum  \
# 0         1      11 Com         b    11 Com b  Radial Velocity        1
# 1         2      11 UMi         b    11 UMi b  Radial Velocity        1
# 2         3      14 And         b    14 And b  Radial Velocity        1
# 3         4      14 Her         b    14 Her b  Radial Velocity        1
# 4         5    16 Cyg B         b  16 Cyg B b  Radial Velocity        1
# ...     ...         ...       ...         ...              ...      ...
# 3833   3834     tau Gem         b   tau Gem b  Radial Velocity        1
# 3834   3835     ups And         b   ups And b  Radial Velocity        3
# 3835   3836     ups And         c   ups And c  Radial Velocity        3
# 3836   3837     ups And         d   ups And d  Radial Velocity        3
# 3837   3838      xi Aql         b    xi Aql b  Radial Velocity        1
#
#         pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  ...  st_bmy  \
# ...

# %%
df.isnull().sum()
# Out:
# rowid               0
# pl_hostname         0
# pl_letter           0
# pl_name             0
# pl_discmethod       0
#                  ...
# st_m1lim         3518
# st_c1            3518
# st_c1err         3519
# st_c1lim         3518
# st_colorn           0
# Length: 355, dtype: int64

# %%
df.loc[df['pl_letter'] == 'b']
print(df)
# Out:
#       rowid pl_hostname pl_letter     pl_name    pl_discmethod  pl_pnum  \
# 0         1      11 Com         b    11 Com b  Radial Velocity        1
# 1         2      11 UMi         b    11 UMi b  Radial Velocity        1
# 2         3      14 And         b    14 And b  Radial Velocity        1
# 3         4      14 Her         b    14 Her b  Radial Velocity        1
# 4         5    16 Cyg B         b  16 Cyg B b  Radial Velocity        1
# ...     ...         ...       ...         ...              ...      ...
# 3833   3834     tau Gem         b   tau Gem b  Radial Velocity        1
# 3834   3835     ups And         b   ups And b  Radial Velocity        3
# 3835   3836     ups And         c   ups And c  Radial Velocity        3
# 3836   3837     ups And         d   ups And d  Radial Velocity        3
# 3837   3838      xi Aql         b    xi Aql b  Radial Velocity        1
#
#         pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  ...  st_bmy  \
# ...

# %%
df.loc[df['pl_discmethod'] == 'Radial Velocity']
print(df)
# Out:
#       rowid pl_hostname pl_letter     pl_name    pl_discmethod  pl_pnum  \
# 0         1      11 Com         b    11 Com b  Radial Velocity        1
# 1         2      11 UMi         b    11 UMi b  Radial Velocity        1
# 2         3      14 And         b    14 And b  Radial Velocity        1
# 3         4      14 Her         b    14 Her b  Radial Velocity        1
# 4         5    16 Cyg B         b  16 Cyg B b  Radial Velocity        1
# ...     ...         ...       ...         ...              ...      ...
# 3833   3834     tau Gem         b   tau Gem b  Radial Velocity        1
# 3834   3835     ups And         b   ups And b  Radial Velocity        3
# 3835   3836     ups And         c   ups And c  Radial Velocity        3
# 3836   3837     ups And         d   ups And d  Radial Velocity        3
# 3837   3838      xi Aql         b    xi Aql b  Radial Velocity        1
#
#         pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  ...  st_bmy  \
# ...

# %%
df = pd.read_csv("exoplanet.csv")

# %%
df.pl_discmethod.unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Orbital Brightness Modulation',
#        'Pulsation Timing Variations', 'Microlensing',
#        'Transit Timing Variations', 'Pulsar Timing'], dtype=object)

# %%
df.hist(column='pl_discmethod')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-bfd2a3374889> in <module>
# ----> 1 df.hist(column='pl_discmethod')
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, **kwargs)
#     206         layout=layout,
#     207         bins=bins,
# --> 208         **kwargs,
#     209     )
#     210
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     387
#     388     if naxes == 0:
# --> 389         raise ValueError("hist method requires numerical columns, nothing to plot.")
#     390
#     391     fig, axes = _subplots(
#
# ...

# %%
df.groupby('pl_discmethod').size()
# Out:
# pl_discmethod
# Astrometry                          1
# Eclipse Timing Variations           9
# Imaging                            44
# Microlensing                       70
# Orbital Brightness Modulation       6
# Pulsar Timing                       6
# Pulsation Timing Variations         2
# Radial Velocity                   687
# Transit                          2998
# Transit Timing Variations          15
# dtype: int64

# %%
df.plot(x ='pl_bmassj', y='pl_radj', kind = 'scatter')

# %%
df.plot(x ='pl_radj', y='st_dist', kind = 'scatter')
